# %%
#Installing the libraries
# !pip install -q -U google-genai gradio
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.2/24.2 MB 31.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.0/56.0 kB 3.6 MB/s eta 0:00:00

# %%
#User input trial
from google import genai
client = genai.Client(api_key="key")

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents="Explain photosynthesis simply"
)

print(response.text)
# Out:
# Imagine plants are like tiny chefs, and their kitchen is mainly their leaves!
#
# Here's how they "cook":
#
# 1.  **Ingredients:**
#     *   **Sunlight:** This is their energy source, like turning on the oven! The green stuff in leaves, called **chlorophyll**, traps this sunlight.
#     *   **Water:** They suck this up from the ground through their roots.
#     *   **Carbon Dioxide:** This is a gas they take in from the air, the same gas we breathe out.
#
# 2.  **The "Cooking" Process:**
#     *   Using the sun's energy, the plant mixes the water and carbon dioxide together inside its leaves.
#
# 3.  **What They Make:**
#     *   **Sugar (Glucose):** This is the plant's food! It gives them energy to grow, make flowers, fruits, and seeds.
#     *   **Oxygen:** As a leftover, or byproduct, they release oxygen gas into the air.
#
# **Why it's amazing for us:** That oxygen they release is what we, and most other living things, breathe to survive!
#
# ...

# %%
#Explain topic feature
from google import genai

client = genai.Client(api_key="AIzaSyBKlpNFZB2UcADYzpxADyoaXfzEYzEEFjc")

topic = input("Enter a topic you want to understand: ")

prompt = f"""
Explain {topic} in very simple words.

Rules:
- Use bullet points
- Add one simple real-life example
- Write like teaching a 10 year old
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nExplanation:\n")
print(response.text)
# Out:
# Enter a topic you want to understand: electricity
#
# Explanation:
#
# Here's electricity explained in a super simple way:
#
# *   **Electricity is like tiny, invisible runners!** Imagine very, very small things called "electrons" that love to run around.
# *   **They carry energy.** When these tiny runners move, they carry a special kind of power with them.
# *   **We make them run in a path.** We build special paths for them, like tiny race tracks (called "circuits"), to make these runners go exactly where we want them.
# *   **When they run, things happen!** As they zoom along their path, they give their energy to different things. This energy can light up a light bulb, make a toy car move, or warm up your toaster.
# *   **It's all about movement.** For electricity to work, these tiny runners need to keep moving from one place to another!
#
# **Here's a simple real-life example:**
#
# Think about water flowing through a garden hose:
# ...

# %%
#Summarizer feature
from google import genai

client = genai.Client(api_key="AIzaSyBKlpNFZB2UcADYzpxADyoaXfzEYzEEFjc")

notes = input("Paste your study notes here: ")

prompt = f"""
Summarize the following text in very simple words.

Rules:
- Keep it short (5-6 bullet points)
- Use easy language
- Do not make it complex

Text:
{notes}
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nSummary:\n")
print(response.text)
# Out:
# Paste your study notes here: Muscles are specialized soft tissues found in humans and animals, comprising thousands of elastic fibers that enable movement, stability, and crucial bodily functions through contraction. The human body contains over 600 skeletal muscles, which make up roughly 40-50% of total body weight. These tissues operate by pulling on bones, which are connected via tendons, rather than pushing, which is why they frequently work in opposing pairs—such as the biceps contracting to bend the arm while the triceps relaxes, and vice versa. Muscles are primarily categorized into three types: skeletal muscles (voluntary, striated muscles used for movement and posture), cardiac muscles (involuntary, specialized tissue found only in the heart), and smooth muscles (involuntary, non-striated tissues found in walls of organs, blood vessels, and the digestive system). Beyond locomotion, muscles are essential for producing heat—accounting for 85% of body heat production—supporting
# ...

# %%
#Quiz generator feature
from google import genai

client = genai.Client(api_key="AIzaSyBKlpNFZB2UcADYzpxADyoaXfzEYzEEFjc")

topic = input("Enter topic for quiz: ")

prompt = f"""
Create 5 multiple choice questions about {topic}.

Rules:
- Each question should have 4 options (A, B, C, D)
- Show correct answer below each question
- Keep language simple
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nQuiz:\n")
print(response.text)
# Out:
# Enter topic for quiz: human heart
#
# Quiz:
#
# Here are 5 multiple-choice questions about the human heart:
#
# ---
#
# **Question 1:**
# What is the main job of your heart?
# A) To help you breathe
# B) To pump blood around your body
# C) To digest your food
# D) To control your thoughts
#
# **Correct Answer: B**
#
# ---
#
# **Question 2:**
# How many chambers (rooms) does the human heart have?
# A) 1
# B) 2
# C) 3
# D) 4
#
# **Correct Answer: D**
#
# ---
#
# **Question 3:**
# Which large blood vessel carries oxygen-rich blood *away* from the heart to the rest of the body?
# A) Vena Cava
# B) Pulmonary Artery
# C) Aorta
# D) Pulmonary Vein
#
# **Correct Answer: C**
#
# ---
#
# **Question 4:**
# What causes the "lub-dub" sound you hear when listening to a heartbeat?
# A) Blood flowing smoothly through vessels
# B) The heart muscle expanding and contracting
# C) Heart valves opening and closing
# D) Air moving in and out of the lungs
#
# **Correct Answer: C**
#
# ---
#
# ...

# %%
#Flashcard generator feature
from google import genai

client = genai.Client(api_key="AIzaSyBKlpNFZB2UcADYzpxADyoaXfzEYzEEFjc")

topic = input("Enter topic for flashcards: ")

prompt = f"""
Create 5 flashcards for {topic}.

Rules:
- Format like this:
  Q: question
  A: answer
- Keep answers short
- Use simple language
"""

response = client.models.generate_content(
    model="gemini-2.5-flash",
    contents=prompt
)

print("\nFlashcards:\n")
print(response.text)
# Out:
# Enter topic for flashcards: plant
#
# Flashcards:
#
# Here are 5 flashcards for plants:
#
# Q: What three things do most plants need to grow?
# A: Sunlight, water, and soil.
#
# Q: What process do plants use to make their own food?
# A: Photosynthesis.
#
# Q: What part of a plant absorbs water and nutrients from the soil?
# A: Roots.
#
# Q: What gas do plants release that humans breathe?
# A: Oxygen.
#
# QQ: What gives plants their green color?
# A: Chlorophyll.

# %%
import gradio as gr
from google import genai

def study_buddy(api_key, language, option, user_input):

    if not api_key:
        return "Please enter your API key."
    if not user_input:
        return "Please enter topic or notes."

    client = genai.Client(api_key=api_key)

    # Language instruction
    lang_instruction = f"Respond in {language}."

    if option == "Explain Topic":
        prompt = f"{lang_instruction} Explain {user_input} in simple words using bullet points and one example."
    elif option == "Summarize Notes":
        prompt = f"{lang_instruction} Summarize this in simple words using 5 bullet points:\n{user_input}"
    elif option == "Generate Quiz":
        prompt = f"{lang_instruction} Create 5 MCQs with answers about {user_input} in simple language."
    elif option == "Create Flashcards":
        prompt = f"{lang_instruction} Create 5 flashcards (Q and A format) about {user_input}."

    try:
        response = client.models.generate_content(
            model="gemini-2.5-flash",
            contents=prompt
        )

        return response.text
    except Exception as e:
        return f"Error: {str(e)}"


#Interface
app = gr.Interface(
    fn=study_buddy,
    inputs=[
        gr.Textbox(label="Enter Gemini API Key", type="password"),
        gr.Dropdown(
            ["English", "Marathi", "Hindi", "Spanish", "French"],
            label="Choose Language"
        ),
        gr.Dropdown(
            ["Explain Topic", "Summarize Notes", "Generate Quiz", "Create Flashcards"],
            label="Choose Feature"
        ),
        gr.Textbox(label="Enter Topic or Notes", lines=6)
    ],
    outputs=gr.Textbox(label="Result"),
    title="<h1><b>📚 AI Study Buddy</b></h1>",
    description="<h3><b>Your Smart Learning Assistant with Multilingual Support!</b></h3>"
)
app.launch()
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://f06c9b1c08064f25a2.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://f06c9b1c08064f25a2.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
